# %% [markdown]
# ### Single Variant Linear Regression Analysis, Regression Model
# Linear regression is one of the most widely used machine learning algorithms in use today. Single Variant (univariant linear regression) is simply just stright line equations.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Single Vairant Linear Regression
x_train = np.array([1, 2]) # X is our intput variable size in 1000sq foot.
y_train = np.array([300, 500]) # Y is our output/ target variable price in £1000s

# %%
# It is common to us m to denote the number of training examples we have, in this case:
print(f"Training Samples (m): {x_train.shape[0]}")
# Out:
# Training Samples (m): 2

# %%
# Lets plot out our rather small data onto a scatter plot
plt.scatter(x_train, y_train, marker = 'X', c = 'r')

# %%
# Lets initalise our weight and biase for our stright line
W = 200 
b = 100

# %%
# Formula for a stright line is and has always been y = W * x + b
# We can write out explicit calculations for each feture in our sample data like so:
f_wb = W * x_train[0] + 100
print(f_wb) # Should be 300, representing £300,000

f_wb = W * x_train[1] + 100
print(f_wb) # Should be 500, representing £500,000
# Out:
# 300
# 500

# %%
"""
For a large number of sample data this can get repetitive, so we use a for loop in a function to itterate over all the 
data and calculate this for us. This is not the final solution but it is a stepping stone for now.
"""

def naive_model_output(x, W, b):
    """
    Computes the output of a basic linear model, using a for loop
    
    Args:
    x - our input feature data
    w - The Weight in our model
    b - The biase in our model
    Returns:
    f_wb - Our outputs, in this case the estimated price of the house.
    """
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = W * x[i] + b
        
    return f_wb

# %%
f_wb = naive_model_output(x_train, W, b)

plt.plot(x_train, f_wb, c='b', label='Linear Regression Prediction')
plt.scatter(x_train, y_train, marker='x', c='r', label='Actual Values')
plt.title("Housing Prices")
plt.xlabel("Price (£)")
plt.ylabel("Sq Foot (Sq F)")
plt.legend()

# %%
"""
The cost function tells us how well our model/ line fits our data. We find the error by taking how far off our prediction
is from the target (the residuals). We square this value to ensure we dont get any negitives. Finally we sum up all the square errors
over the whole dataset and divide by (m) - number of samples to find the avrage squared error. In these examples we will
dividing by (2*m). This whole operation is known as the squared error cost function.
"""
# These next few cells will look at loss and the cost function for univariant linear regression
# Using the same small sample data as above.

x_train = np.array([1, 2])
y_train = np.array([300, 500])

# %%
def compute_cost(x, W, b, y):
    """
    This function will output the cost by looping over each example in our sample dataset.
    Firstly f_wb, is calculated.
    This then used to find the squared difference between the predicted values and the acutal y values (y_train).
    Finally this values is added to the toatal cost.
    """    
    
    m = x.shape[0]
    
    cost_sum = 0
    
    for i in range(m):
        f_wb = W * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum += cost
    cost_sum = cost_sum/2*m
    
    return cost_sum

# %%
# Testing compute cost for W, b = 50, 600 and W, b = 200, 100

print("Cost for W = 50, b = 600: ")
print(compute_cost(x_train, 50, 600, y_train))

print("Cost for W = 200, b = 100: ")
print(compute_cost(x_train, 200, 100, y_train))
# Out:
# Cost for W = 50, b = 600:
# 162500.0
# Cost for W = 200, b = 100:
# 0.0

# %%
# Computing the gradient for given weights and biases

def compute_gradient(x, y, w, b):
    """
    This function computes the gradient for our single varient linear regression model.
    Args:
    x - numpy array (m, ) m examples, these are our input features.
    y - numpy array (m, ) m examples, these are our targer variables.
    w - Scalar, model parameter (weight).
    b - Scalar, model parameter (biase).
    Returns:
    dj_dw - Scaler, The gradient of the cost for the parameter w.
    dj_db - Scalar, The gradient of the cost for the parameter b.
    """
    
    m = x.shape[0]
    dj_dw = 0
    dj_db = 0
    
    for i in range(m):
        f_wb = w * x[i] + b
        dj_dw += (f_wb - y) * x[i]
        dj_db += (f_wb - y)
        dj_dw /= m
        dj_db /= m
        
    return dj_dw, dj_db

# %%
# Performing gradient descent

def gradient_descent(x, y, w_in, b_in, alpha, num_iters, cost_function, gradient_function):
    """
    Performs graident descent to better fit w and b.

    Args:
    
    
    Returns:
    w - 
    b - 
    J_history -
    wb_history -
    """
    
    # A list to store the cost performence.
    j_history = []
    # A list to store the historical values of w and b.
    wb_history = []
    
    for i in range(num_iters):
        dj_dw, dj_db = compute_gradient(x, y, w, b) # Use the pervious gradient function we made
        
        # Update our parameters
        w = w - alpha * dj_dw
        b = b - alpha * dj_dw
        
        if i < 100000:
            j_history.append(cost_function(x, y, w, b)) # Use the pervious cost function we made
            wb_history.append([w,b])
